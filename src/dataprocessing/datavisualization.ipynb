# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/cleansed.csv', index_col=0)
df
# Out:
#       Net Income Before Taxes  Total Liabilities  \
# 0                    0.256721           0.009259
# 1                    0.253811           0.009970
# 2                    0.246107           0.010004
# 3                    0.255270           0.007716
# 4                    0.206828           0.000024
# ...                       ...                ...
# 1983                 0.217495           0.002465
# 1984                 0.208303           0.004859
# 1985                 0.229268           0.004540
# 1986                 0.217914           0.004411
# 1987                 0.224808           0.004769
#
#       Income Available to Common Excluding Extraordinary Items       Low  \
# 0                                              0.242315         0.041986
# 1                                              0.238286         0.029285
# 2                                              0.230782         0.038691
# 3                                              0.238935         0.045459
# ...

# %%
df.plot(subplots=True, figsize=(10,17))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>], dtype=object)

# %%
df.plot(legend=False, figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
print(list(df))
# Out:
# ['Net Income Before Taxes', 'Total Liabilities', 'Income Available to Common Excluding Extraordinary Items', 'Low', 'avg Volume', "Total Liabilities & Shareholders' Equity", 'Diluted Net Income', 'Net Income Before Extraordinary Items', 'Total Assets', 'Diluted Normalized EPS', 'Diluted Weighted Average Shares', 'Total Equity', 'Diluted EPS Excluding Extraordinary Items', 'Total Common Shares Outstanding', 'High', 'Net Income After Taxes', 'Net Income']

# %%
df['Diluted Normalized EPS'].plot(ylim=[0,0.007])
# Out:
# <AxesSubplot:>

# %%
df['Diluted Normalized EPS'].mean()
# Out:
# 0.0018452602347801843

# %%
df.drop(['Diluted Normalized EPS', 'Diluted EPS Excluding Extraordinary Items'], axis=1, inplace=True)

# %%
df.plot(subplots=True, figsize=(10,34))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
df.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
df_without_label = df.drop(['Low', 'High'], axis=1)
df_without_label.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
len(list(df_without_label))
# Out:
# 13
